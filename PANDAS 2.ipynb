# %%
import pandas as pd

# %%
df=pd.read_excel("Sales Analysis Report (1) (1) (2).xlsx")
df
# Out:
#        OrderNumber  OrderDate  Ship Date  Customer Name Index      Channel  \
# 0      SO - 000225 2017-01-01 2017-01-13                   28    Wholesale
# 1     SO - 0003378 2017-01-01 2017-01-06                    7  Distributor
# 2     SO - 0003901 2017-01-01 2017-01-05                   12    Wholesale
# 3     SO - 0005126 2017-01-01 2017-01-17                    5    Wholesale
# 4     SO - 0005614 2017-01-01 2017-01-07                   27       Export
# ...            ...        ...        ...                  ...          ...
# 7986  SO - 0005237 2019-12-12 2019-12-16                   41    Wholesale
# 7987  SO - 0005477 2019-12-12 2019-12-27                   28  Distributor
# 7988  SO - 0006936 2019-12-12 2019-12-27                   30    Wholesale
# 7989  SO - 0007126 2019-12-12 2019-12-25                    6  Distributor
# 7990  SO - 0007668 2019-12-12 2019-12-25                    4    Wholesale
#
#      Currency Code Warehouse Code  Region Index  Product  Index  \
# ...

# %%
df.shape
# Out:
# (7991, 13)

# %%
df.columns
# Out:
# Index(['OrderNumber', 'OrderDate', 'Ship Date', 'Customer Name Index',
#        'Channel', 'Currency Code', 'Warehouse Code', 'Region Index',
#        'Product  Index', 'Order Quantity', 'Unit Price', 'Total Unit Cost',
#        'Total Revenue'],
#       dtype='object')

# %%
df.head(10)
# Out:
#     OrderNumber  OrderDate  Ship Date  Customer Name Index      Channel  \
# 0   SO - 000225 2017-01-01 2017-01-13                   28    Wholesale
# 1  SO - 0003378 2017-01-01 2017-01-06                    7  Distributor
# 2  SO - 0003901 2017-01-01 2017-01-05                   12    Wholesale
# 3  SO - 0005126 2017-01-01 2017-01-17                    5    Wholesale
# 4  SO - 0005614 2017-01-01 2017-01-07                   27       Export
# 5  SO - 0005781 2017-01-01 2017-01-15                   44    Wholesale
# 6  SO - 0002911 2017-01-02 2017-01-15                   37    Wholesale
# 7  SO - 0003527 2017-01-02 2017-01-19                    8    Wholesale
# 8  SO - 0004792 2017-01-02 2017-01-13                   14    Wholesale
# 9  SO - 0005414 2017-01-02 2017-01-05                   47    Wholesale
#
#   Currency Code Warehouse Code  Region Index  Product  Index  Order Quantity  \
# 0           NZD         AXW291            71              11               6
# ...

# %%
df.tail()
# Out:
#        OrderNumber  OrderDate  Ship Date  Customer Name Index      Channel  \
# 7986  SO - 0005237 2019-12-12 2019-12-16                   41    Wholesale
# 7987  SO - 0005477 2019-12-12 2019-12-27                   28  Distributor
# 7988  SO - 0006936 2019-12-12 2019-12-27                   30    Wholesale
# 7989  SO - 0007126 2019-12-12 2019-12-25                    6  Distributor
# 7990  SO - 0007668 2019-12-12 2019-12-25                    4    Wholesale
#
#      Currency Code Warehouse Code  Region Index  Product  Index  \
# 7986           NZD         FLR025            93               9
# 7987           AUD         FLR025            56               2
# 7988           NZD         FLR025            66               1
# 7989           USD         FLR025            31               5
# 7990           NZD         FLR025            65              13
#
#       Order Quantity  Unit Price  Total Unit Cost  Total Revenue
# ...

# %%
df.isnull().sum()
# Out:
# OrderNumber            0
# OrderDate              0
# Ship Date              0
# Customer Name Index    0
# Channel                0
# Currency Code          0
# Warehouse Code         0
# Region Index           0
# Product  Index         0
# Order Quantity         0
# Unit Price             0
# Total Unit Cost        0
# Total Revenue          0
# dtype: int64

# %%
df.tail().isnull()
# Out:
#       OrderNumber  OrderDate  Ship Date  Customer Name Index  Channel  \
# 7986        False      False      False                False    False
# 7987        False      False      False                False    False
# 7988        False      False      False                False    False
# 7989        False      False      False                False    False
# 7990        False      False      False                False    False
#
#       Currency Code  Warehouse Code  Region Index  Product  Index  \
# 7986          False           False         False           False
# 7987          False           False         False           False
# 7988          False           False         False           False
# 7989          False           False         False           False
# 7990          False           False         False           False
#
#       Order Quantity  Unit Price  Total Unit Cost  Total Revenue
# 7986           False       False            False          False
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7991 entries, 0 to 7990
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   OrderNumber          7991 non-null   object
#  1   OrderDate            7991 non-null   datetime64[ns]
#  2   Ship Date            7991 non-null   datetime64[ns]
#  3   Customer Name Index  7991 non-null   int64
#  4   Channel              7991 non-null   object
#  5   Currency Code        7991 non-null   object
#  6   Warehouse Code       7991 non-null   object
#  7   Region Index         7991 non-null   int64
#  8   Product  Index       7991 non-null   int64
#  9   Order Quantity       7991 non-null   int64
#  10  Unit Price           7991 non-null   float64
#  11  Total Unit Cost      7991 non-null   float64
#  12  Total Revenue        7991 non-null   float64
# dtypes: datetime64[ns](2), float64(3), int64(4), object(4)
# memory usage: 811.7+ KB

# %%
df.describe()
# Out:
#                            OrderDate                      Ship Date  \
# count                           7991                           7991
# mean   2018-06-22 01:36:56.944061952  2018-07-02 12:04:35.710173952
# min              2017-01-01 00:00:00            2017-01-05 00:00:00
# 25%              2017-09-23 00:00:00            2017-10-03 00:00:00
# 50%              2018-06-20 00:00:00            2018-07-01 00:00:00
# 75%              2019-03-20 00:00:00            2019-04-01 00:00:00
# max              2019-12-12 00:00:00            2019-12-28 00:00:00
# std                              NaN                            NaN
#
#        Customer Name Index  Region Index  Product  Index  Order Quantity  \
# count          7991.000000   7991.000000     7991.000000     7991.000000
# mean             25.457014     50.454261        6.340383        8.456889
# min               1.000000      1.000000        1.000000        5.000000
# ...

# %%
df["Channel"].nunique()
# Out:
# 3

# %%
df["Channel"].unique()
# Out:
# array(['Wholesale', 'Distributor', 'Export'], dtype=object)

# %%
df["Channel"].value_counts()
# Out:
# Channel
# Wholesale      4286
# Distributor    2510
# Export         1195
# Name: count, dtype: int64

# %%
df["Currency Code"].nunique()
# Out:
# 5

# %%
df["Currency Code"].unique()
# Out:
# array(['NZD', 'USD', 'GBP', 'EUR', 'AUD'], dtype=object)

# %%
df["Currency Code"].value_counts()
# Out:
# Currency Code
# NZD    3026
# USD    2323
# AUD    1309
# GBP     669
# EUR     664
# Name: count, dtype: int64

# %%
#to drop the column
df.drop(columns=["Ship Date"],inplace=True)

# %%
df
# Out:
#        OrderNumber  OrderDate  Customer Name Index      Channel Currency Code  \
# 0      SO - 000225 2017-01-01                   28    Wholesale           NZD
# 1     SO - 0003378 2017-01-01                    7  Distributor           NZD
# 2     SO - 0003901 2017-01-01                   12    Wholesale           NZD
# 3     SO - 0005126 2017-01-01                    5    Wholesale           USD
# 4     SO - 0005614 2017-01-01                   27       Export           NZD
# ...            ...        ...                  ...          ...           ...
# 7986  SO - 0005237 2019-12-12                   41    Wholesale           NZD
# 7987  SO - 0005477 2019-12-12                   28  Distributor           AUD
# 7988  SO - 0006936 2019-12-12                   30    Wholesale           NZD
# 7989  SO - 0007126 2019-12-12                    6  Distributor           USD
# 7990  SO - 0007668 2019-12-12                    4    Wholesale           NZD
#
# ...

# %%
# to rename a column
df.rename(columns={"Customer Name Index":"customers"},inplace=True)

# %%
df
# Out:
#        OrderNumber  OrderDate  customers      Channel Currency Code  \
# 0      SO - 000225 2017-01-01         28    Wholesale           NZD
# 1     SO - 0003378 2017-01-01          7  Distributor           NZD
# 2     SO - 0003901 2017-01-01         12    Wholesale           NZD
# 3     SO - 0005126 2017-01-01          5    Wholesale           USD
# 4     SO - 0005614 2017-01-01         27       Export           NZD
# ...            ...        ...        ...          ...           ...
# 7986  SO - 0005237 2019-12-12         41    Wholesale           NZD
# 7987  SO - 0005477 2019-12-12         28  Distributor           AUD
# 7988  SO - 0006936 2019-12-12         30    Wholesale           NZD
# 7989  SO - 0007126 2019-12-12          6  Distributor           USD
# 7990  SO - 0007668 2019-12-12          4    Wholesale           NZD
#
#      Warehouse Code  Region Index  Product  Index  Order Quantity  Unit Price  \
# ...

# %%
df.rename(columns={"Currency Code":"currency name"},inplace=True)

# %%
df
# Out:
#        OrderNumber  OrderDate  customers      Channel currency name  \
# 0      SO - 000225 2017-01-01         28    Wholesale           NZD
# 1     SO - 0003378 2017-01-01          7  Distributor           NZD
# 2     SO - 0003901 2017-01-01         12    Wholesale           NZD
# 3     SO - 0005126 2017-01-01          5    Wholesale           USD
# 4     SO - 0005614 2017-01-01         27       Export           NZD
# ...            ...        ...        ...          ...           ...
# 7986  SO - 0005237 2019-12-12         41    Wholesale           NZD
# 7987  SO - 0005477 2019-12-12         28  Distributor           AUD
# 7988  SO - 0006936 2019-12-12         30    Wholesale           NZD
# 7989  SO - 0007126 2019-12-12          6  Distributor           USD
# 7990  SO - 0007668 2019-12-12          4    Wholesale           NZD
#
#      Warehouse Code  Region Index  Product  Index  Order Quantity  Unit Price  \
# ...

# %%
df["Total Revenue"].sum()
# Out:
# 154573140.60000002

# %%
df["Order Quantity"].sum()
# Out:
# 67579

# %%
a=df["Total Revenue"].sum()
print(f"the total revenue is {a}")
# Out:
# the total revenue is 154573140.60000002

# %% [markdown]
# TASK

# %%
df["Warehouse Code"].unique()
# Out:
# array(['AXW291', 'GUT930', 'NXH382', 'FLR025'], dtype=object)

# %%
df["Warehouse Code"].nunique()
# Out:
# 4

# %%
df["Warehouse Code"].value_counts()
# Out:
# Warehouse Code
# AXW291    3756
# GUT930    1850
# NXH382    1569
# FLR025     816
# Name: count, dtype: int64

# %%
df["Region Index"].nunique()
# Out:
# 100

# %%
df["Region Index"].unique()
# Out:
# array([ 71,  54,  58,  29,  31,  78,   2,  77,  82,   5,  42,  87,  80,
#         38,  97,  88,   6,  95,  37,  53,  60,  47,  30,  63,  65,  27,
#         28,  83,  59,  99,  92,  23,  70,  25,  11, 100,  68,  39,  98,
#         41,  17,  72,  33,  64,  21,  19,   9,  46,  91,  79,  43,  10,
#         57,  84,   3,  55,  44,  51,  52,  36,   7,  40,  49,  16,  48,
#         26,  94,  66,  76,  22,   8,  34,  13,   1,  20,  15,  93,  50,
#         45,   4,  24,  35,  12,  14,  85,  73,  18,  62,  69,  89,  75,
#         81,  96,  74,  56,  90,  32,  67,  61,  86], dtype=int64)

# %%
df["Region Index"].value_counts()
# Out:
# Region Index
# 24    106
# 23    101
# 6     100
# 63     99
# 67     96
#      ...
# 14     64
# 15     63
# 75     62
# 32     62
# 56     60
# Name: count, Length: 100, dtype: int64

# %%
df["customers"].unique()
# Out:
# array([28,  7, 12,  5, 27, 44, 37,  8, 14, 47, 22, 39, 46, 45, 20, 36, 30,
#        11, 17, 29, 41, 33, 34, 50, 43, 48, 42, 35,  9, 26, 31, 10,  4, 21,
#        13, 49, 32, 23, 40, 18,  6,  1,  3, 24, 38, 15,  2, 19, 16, 25],
#       dtype=int64)

# %%
df["customers"].nunique()
# Out:
# 50

# %%
df["customers"].value_counts()
# Out:
# customers
# 12    210
# 18    186
# 3     181
# 29    179
# 11    178
# 34    176
# 39    176
# 17    175
# 32    173
# 48    172
# 13    171
# 9     171
# 47    168
# 4     167
# 20    167
# 19    165
# 21    164
# 23    164
# 50    163
# 25    162
# 41    161
# 42    161
# 30    159
# 5     159
# 10    158
# 46    157
# 14    157
# 33    156
# 36    156
# 45    156
# 44    156
# 7     153
# 26    153
# 1     152
# 37    152
# 49    152
# 31    152
# 24    151
# 43    151
# 40    150
# 38    150
# 35    145
# 28    145
# 27    144
# 6     143
# 8     142
# 15    142
# 22    140
# 2     135
# 16    135
# Name: count, dtype: int64

# %%
df["Region Index"].unique()
# Out:
# array([ 71,  54,  58,  29,  31,  78,   2,  77,  82,   5,  42,  87,  80,
#         38,  97,  88,   6,  95,  37,  53,  60,  47,  30,  63,  65,  27,
#         28,  83,  59,  99,  92,  23,  70,  25,  11, 100,  68,  39,  98,
#         41,  17,  72,  33,  64,  21,  19,   9,  46,  91,  79,  43,  10,
#         57,  84,   3,  55,  44,  51,  52,  36,   7,  40,  49,  16,  48,
#         26,  94,  66,  76,  22,   8,  34,  13,   1,  20,  15,  93,  50,
#         45,   4,  24,  35,  12,  14,  85,  73,  18,  62,  69,  89,  75,
#         81,  96,  74,  56,  90,  32,  67,  61,  86], dtype=int64)

# %%
df["Region Index"].nunique()
# Out:
# 100

# %%
df["Region Index"].value_counts()
# Out:
# Region Index
# 24    106
# 23    101
# 6     100
# 63     99
# 67     96
#      ...
# 14     64
# 15     63
# 75     62
# 32     62
# 56     60
# Name: count, Length: 100, dtype: int64

# %%
df.rename(columns={"Product  Index":"product"},inplace=True)

# %%
df
# Out:
#        OrderNumber  OrderDate  customers      Channel currency name  \
# 0      SO - 000225 2017-01-01         28    Wholesale           NZD
# 1     SO - 0003378 2017-01-01          7  Distributor           NZD
# 2     SO - 0003901 2017-01-01         12    Wholesale           NZD
# 3     SO - 0005126 2017-01-01          5    Wholesale           USD
# 4     SO - 0005614 2017-01-01         27       Export           NZD
# ...            ...        ...        ...          ...           ...
# 7986  SO - 0005237 2019-12-12         41    Wholesale           NZD
# 7987  SO - 0005477 2019-12-12         28  Distributor           AUD
# 7988  SO - 0006936 2019-12-12         30    Wholesale           NZD
# 7989  SO - 0007126 2019-12-12          6  Distributor           USD
# 7990  SO - 0007668 2019-12-12          4    Wholesale           NZD
#
#      Warehouse Code  Region Index  product  Order Quantity  Unit Price  \
# 0            AXW291            71       11               6      2499.1
# ...

# %%
df.rename(columns={"Region Index":"Region"},inplace=True)

# %%
df
# Out:
#        OrderNumber  OrderDate  customers      Channel currency name  \
# 0      SO - 000225 2017-01-01         28    Wholesale           NZD
# 1     SO - 0003378 2017-01-01          7  Distributor           NZD
# 2     SO - 0003901 2017-01-01         12    Wholesale           NZD
# 3     SO - 0005126 2017-01-01          5    Wholesale           USD
# 4     SO - 0005614 2017-01-01         27       Export           NZD
# ...            ...        ...        ...          ...           ...
# 7986  SO - 0005237 2019-12-12         41    Wholesale           NZD
# 7987  SO - 0005477 2019-12-12         28  Distributor           AUD
# 7988  SO - 0006936 2019-12-12         30    Wholesale           NZD
# 7989  SO - 0007126 2019-12-12          6  Distributor           USD
# 7990  SO - 0007668 2019-12-12          4    Wholesale           NZD
#
#      Warehouse Code  Region  product  Order Quantity  Unit Price  \
# 0            AXW291      71       11               6      2499.1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7991 entries, 0 to 7990
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   OrderNumber      7991 non-null   object
#  1   OrderDate        7991 non-null   datetime64[ns]
#  2   customers        7991 non-null   int64
#  3   Channel          7991 non-null   object
#  4   currency name    7991 non-null   object
#  5   Warehouse Code   7991 non-null   object
#  6   Region           7991 non-null   int64
#  7   product          7991 non-null   int64
#  8   Order Quantity   7991 non-null   int64
#  9   Unit Price       7991 non-null   float64
#  10  Total Unit Cost  7991 non-null   float64
#  11  Total Revenue    7991 non-null   float64
# dtypes: datetime64[ns](1), float64(3), int64(4), object(4)
# memory usage: 749.3+ KB

# %%
df["Total Revenue"].mean()
# Out:
# 19343.403904392446

# %%
df["Order Quantity"].min()
# Out:
# 5

# %%
df["Unit Price"].max()
# Out:
# 6566.0

# %%
df
# Out:
#        OrderNumber  OrderDate  customers      Channel currency name  \
# 0      SO - 000225 2017-01-01         28    Wholesale           NZD
# 1     SO - 0003378 2017-01-01          7  Distributor           NZD
# 2     SO - 0003901 2017-01-01         12    Wholesale           NZD
# 3     SO - 0005126 2017-01-01          5    Wholesale           USD
# 4     SO - 0005614 2017-01-01         27       Export           NZD
# ...            ...        ...        ...          ...           ...
# 7986  SO - 0005237 2019-12-12         41    Wholesale           NZD
# 7987  SO - 0005477 2019-12-12         28  Distributor           AUD
# 7988  SO - 0006936 2019-12-12         30    Wholesale           NZD
# 7989  SO - 0007126 2019-12-12          6  Distributor           USD
# 7990  SO - 0007668 2019-12-12          4    Wholesale           NZD
#
#      Warehouse Code  Region  product  Order Quantity  Unit Price  \
# 0            AXW291      71       11               6      2499.1
# ...

# %%
df["Total Revenue"].sum()
# Out:
# 154573140.60000002

# %%
df.groupby("Channel")["Total Revenue"].sum()
# Out:
# Channel
# Distributor    48969690.3
# Export         22636874.6
# Wholesale      82966575.7
# Name: Total Revenue, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7991 entries, 0 to 7990
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   OrderNumber      7991 non-null   object
#  1   OrderDate        7991 non-null   datetime64[ns]
#  2   customers        7991 non-null   int64
#  3   Channel          7991 non-null   object
#  4   currency name    7991 non-null   object
#  5   Warehouse Code   7991 non-null   object
#  6   Region           7991 non-null   int64
#  7   product          7991 non-null   int64
#  8   Order Quantity   7991 non-null   int64
#  9   Unit Price       7991 non-null   float64
#  10  Total Unit Cost  7991 non-null   float64
#  11  Total Revenue    7991 non-null   float64
# dtypes: datetime64[ns](1), float64(3), int64(4), object(4)
# memory usage: 749.3+ KB

# %%
df.groupby("currency name")["Order Quantity"].sum()
# Out:
# currency name
# AUD    11013
# EUR     5610
# GBP     5680
# NZD    25623
# USD    19653
# Name: Order Quantity, dtype: int64

# %%
df.groupby("Channel")["Total Revenue"].sum().idxmax()
# Out:
# 'Wholesale'

# %%
dfmin=df.groupby("Channel")["Total Revenue"].sum()

# %%
dfmin.idxmax()
# Out:
# 'Wholesale'

# %%
#we can pass two aggregate function
df.groupby("Channel")["Total Revenue"].agg(["max","sum"])
# Out:
#                  max         sum
# Channel
# Distributor  78550.8  48969690.3
# Export       77505.6  22636874.6
# Wholesale    78711.6  82966575.7

# %%
#passing multiple expression or value
df.groupby("Channel")[["Total Revenue","Order Quantity"]].sum()
# Out:
#              Total Revenue  Order Quantity
# Channel
# Distributor     48969690.3           21113
# Export          22636874.6           10135
# Wholesale       82966575.7           36331

# %%
#to convert the data type
df["customers"]=df["customers"].astype("float")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7991 entries, 0 to 7990
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   OrderNumber      7991 non-null   object
#  1   OrderDate        7991 non-null   datetime64[ns]
#  2   customers        7991 non-null   float64
#  3   Channel          7991 non-null   object
#  4   currency name    7991 non-null   object
#  5   Warehouse Code   7991 non-null   object
#  6   Region           7991 non-null   int64
#  7   product          7991 non-null   int64
#  8   Order Quantity   7991 non-null   int64
#  9   Unit Price       7991 non-null   float64
#  10  Total Unit Cost  7991 non-null   float64
#  11  Total Revenue    7991 non-null   float64
# dtypes: datetime64[ns](1), float64(4), int64(3), object(4)
# memory usage: 749.3+ KB

# %%
df["year"]=df["OrderDate"].dt.year

# %%
df
# Out:
#        OrderNumber  OrderDate  customers      Channel currency name  \
# 0      SO - 000225 2017-01-01       28.0    Wholesale           NZD
# 1     SO - 0003378 2017-01-01        7.0  Distributor           NZD
# 2     SO - 0003901 2017-01-01       12.0    Wholesale           NZD
# 3     SO - 0005126 2017-01-01        5.0    Wholesale           USD
# 4     SO - 0005614 2017-01-01       27.0       Export           NZD
# ...            ...        ...        ...          ...           ...
# 7986  SO - 0005237 2019-12-12       41.0    Wholesale           NZD
# 7987  SO - 0005477 2019-12-12       28.0  Distributor           AUD
# 7988  SO - 0006936 2019-12-12       30.0    Wholesale           NZD
# 7989  SO - 0007126 2019-12-12        6.0  Distributor           USD
# 7990  SO - 0007668 2019-12-12        4.0    Wholesale           NZD
#
#      Warehouse Code  Region  product  Order Quantity  Unit Price  \
# 0            AXW291      71       11               6      2499.1
# ...

# %%
df["month"]=df["OrderDate"].dt.month
df.head(2)
# Out:
#     OrderNumber  OrderDate  customers      Channel currency name  \
# 0   SO - 000225 2017-01-01       28.0    Wholesale           NZD
# 1  SO - 0003378 2017-01-01        7.0  Distributor           NZD
#
#   Warehouse Code  Region  product  Order Quantity  Unit Price  \
# 0         AXW291      71       11               6      2499.1
# 1         AXW291      54        7              11      2351.7
#
#    Total Unit Cost  Total Revenue  year  month
# 0         1824.343        14994.6  2017      1
# 1         1269.918        25868.7  2017      1

# %%
df["month"]=df["OrderDate"].dt.month_name()
df
# Out:
#        OrderNumber  OrderDate  customers      Channel currency name  \
# 0      SO - 000225 2017-01-01       28.0    Wholesale           NZD
# 1     SO - 0003378 2017-01-01        7.0  Distributor           NZD
# 2     SO - 0003901 2017-01-01       12.0    Wholesale           NZD
# 3     SO - 0005126 2017-01-01        5.0    Wholesale           USD
# 4     SO - 0005614 2017-01-01       27.0       Export           NZD
# ...            ...        ...        ...          ...           ...
# 7986  SO - 0005237 2019-12-12       41.0    Wholesale           NZD
# 7987  SO - 0005477 2019-12-12       28.0  Distributor           AUD
# 7988  SO - 0006936 2019-12-12       30.0    Wholesale           NZD
# 7989  SO - 0007126 2019-12-12        6.0  Distributor           USD
# 7990  SO - 0007668 2019-12-12        4.0    Wholesale           NZD
#
#      Warehouse Code  Region  product  Order Quantity  Unit Price  \
# 0            AXW291      71       11               6      2499.1
# ...

# %%
df.groupby("month")["Total Revenue"].sum()
# Out:
# month
# April        12317099.1
# August       13584591.7
# December     11850276.6
# February     11699573.5
# January      13026119.9
# July         12457651.7
# June         12087617.4
# March        14403894.5
# May          13328678.5
# November     12690885.4
# October      13312310.4
# September    13814441.9
# Name: Total Revenue, dtype: float64

# %%
df["week day"]=df["OrderDate"].dt.day_name()
df
# Out:
#        OrderNumber  OrderDate  customers      Channel currency name  \
# 0      SO - 000225 2017-01-01       28.0    Wholesale           NZD
# 1     SO - 0003378 2017-01-01        7.0  Distributor           NZD
# 2     SO - 0003901 2017-01-01       12.0    Wholesale           NZD
# 3     SO - 0005126 2017-01-01        5.0    Wholesale           USD
# 4     SO - 0005614 2017-01-01       27.0       Export           NZD
# ...            ...        ...        ...          ...           ...
# 7986  SO - 0005237 2019-12-12       41.0    Wholesale           NZD
# 7987  SO - 0005477 2019-12-12       28.0  Distributor           AUD
# 7988  SO - 0006936 2019-12-12       30.0    Wholesale           NZD
# 7989  SO - 0007126 2019-12-12        6.0  Distributor           USD
# 7990  SO - 0007668 2019-12-12        4.0    Wholesale           NZD
#
#      Warehouse Code  Region  product  Order Quantity  Unit Price  \
# 0            AXW291      71       11               6      2499.1
# ...

# %%
df.groupby("week day")["Total Revenue"].sum()
# Out:
# week day
# Friday       22560856.4
# Monday       21224005.4
# Saturday     21234658.4
# Sunday       22309619.8
# Thursday     23012322.5
# Tuesday      21545712.6
# Wednesday    22685965.5
# Name: Total Revenue, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7991 entries, 0 to 7990
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   OrderNumber      7991 non-null   object
#  1   OrderDate        7991 non-null   datetime64[ns]
#  2   customers        7991 non-null   float64
#  3   Channel          7991 non-null   object
#  4   currency name    7991 non-null   object
#  5   Warehouse Code   7991 non-null   object
#  6   Region           7991 non-null   int64
#  7   product          7991 non-null   int64
#  8   Order Quantity   7991 non-null   int64
#  9   Unit Price       7991 non-null   float64
#  10  Total Unit Cost  7991 non-null   float64
#  11  Total Revenue    7991 non-null   float64
#  12  year             7991 non-null   int32
#  13  month            7991 non-null   object
#  14  week day         7991 non-null   object
# dtypes: datetime64[ns](1), float64(4), int32(1), int64(3), object(6)
# ...

# %%
df["manufacture cost"]=df["Order Quantity"]*df["Total Unit Cost"]
df
# Out:
#        OrderNumber  OrderDate  customers      Channel currency name  \
# 0      SO - 000225 2017-01-01       28.0    Wholesale           NZD
# 1     SO - 0003378 2017-01-01        7.0  Distributor           NZD
# 2     SO - 0003901 2017-01-01       12.0    Wholesale           NZD
# 3     SO - 0005126 2017-01-01        5.0    Wholesale           USD
# 4     SO - 0005614 2017-01-01       27.0       Export           NZD
# ...            ...        ...        ...          ...           ...
# 7986  SO - 0005237 2019-12-12       41.0    Wholesale           NZD
# 7987  SO - 0005477 2019-12-12       28.0  Distributor           AUD
# 7988  SO - 0006936 2019-12-12       30.0    Wholesale           NZD
# 7989  SO - 0007126 2019-12-12        6.0  Distributor           USD
# 7990  SO - 0007668 2019-12-12        4.0    Wholesale           NZD
#
#      Warehouse Code  Region  product  Order Quantity  Unit Price  \
# 0            AXW291      71       11               6      2499.1
# ...

# %%
df["profit"]=df["Total Revenue"]-df["manufacture cost"]
df
# Out:
#        OrderNumber  OrderDate  customers      Channel currency name  \
# 0      SO - 000225 2017-01-01       28.0    Wholesale           NZD
# 1     SO - 0003378 2017-01-01        7.0  Distributor           NZD
# 2     SO - 0003901 2017-01-01       12.0    Wholesale           NZD
# 3     SO - 0005126 2017-01-01        5.0    Wholesale           USD
# 4     SO - 0005614 2017-01-01       27.0       Export           NZD
# ...            ...        ...        ...          ...           ...
# 7986  SO - 0005237 2019-12-12       41.0    Wholesale           NZD
# 7987  SO - 0005477 2019-12-12       28.0  Distributor           AUD
# 7988  SO - 0006936 2019-12-12       30.0    Wholesale           NZD
# 7989  SO - 0007126 2019-12-12        6.0  Distributor           USD
# 7990  SO - 0007668 2019-12-12        4.0    Wholesale           NZD
#
#      Warehouse Code  Region  product  Order Quantity  Unit Price  \
# 0            AXW291      71       11               6      2499.1
# ...

# %%
df
# Out:
#        OrderNumber  OrderDate  customers      Channel currency name  \
# 0      SO - 000225 2017-01-01       28.0    Wholesale           NZD
# 1     SO - 0003378 2017-01-01        7.0  Distributor           NZD
# 2     SO - 0003901 2017-01-01       12.0    Wholesale           NZD
# 3     SO - 0005126 2017-01-01        5.0    Wholesale           USD
# 4     SO - 0005614 2017-01-01       27.0       Export           NZD
# ...            ...        ...        ...          ...           ...
# 7986  SO - 0005237 2019-12-12       41.0    Wholesale           NZD
# 7987  SO - 0005477 2019-12-12       28.0  Distributor           AUD
# 7988  SO - 0006936 2019-12-12       30.0    Wholesale           NZD
# 7989  SO - 0007126 2019-12-12        6.0  Distributor           USD
# 7990  SO - 0007668 2019-12-12        4.0    Wholesale           NZD
#
#      Warehouse Code  Region  product  Order Quantity  Unit Price  \
# 0            AXW291      71       11               6      2499.1
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#channel vs total revenue
sns.barplot(x="Channel",y="Total Revenue",data=df)
# Out:
# <Axes: xlabel='Channel', ylabel='Total Revenue'>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7991 entries, 0 to 7990
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   OrderNumber       7991 non-null   object
#  1   OrderDate         7991 non-null   datetime64[ns]
#  2   customers         7991 non-null   float64
#  3   Channel           7991 non-null   object
#  4   currency name     7991 non-null   object
#  5   Warehouse Code    7991 non-null   object
#  6   Region            7991 non-null   int64
#  7   product           7991 non-null   int64
#  8   Order Quantity    7991 non-null   int64
#  9   Unit Price        7991 non-null   float64
#  10  Total Unit Cost   7991 non-null   float64
#  11  Total Revenue     7991 non-null   float64
#  12  year              7991 non-null   int32
#  13  month             7991 non-null   object
#  14  week day          7991 non-null   object
#  15  manufacture cost  7991 non-null   float64
# ...

# %%
sns.barplot(x="Channel",y="Total Revenue",data=df,estimator=sum)
# Out:
# <Axes: xlabel='Channel', ylabel='Total Revenue'>

# %%
sns.barplot(x="Channel",y="Total Revenue",data=df,estimator=sum)
plt.xlabel("CHANNELS")
plt.ylabel("sum of revenue")
plt.show()

# %%
df2=df.groupby("year")["Total Revenue"].sum()
df2
# Out:
# year
# 2017    52580534.7
# 2018    53463661.7
# 2019    48528944.2
# Name: Total Revenue, dtype: float64

# %%
df2.plot(kind="line",marker="o",color="green",linestyle="--")
df_unique=df2.index
plt.xticks(df_unique)
plt.show()

# %%
df2.plot(kind="pie",labels=df2.index,autopct="%1.1f%%")
plt.show()

# %%
df3=df.groupby("Channel")["Total Revenue"].sum()

# %%
df3
# Out:
# Channel
# Distributor    48969690.3
# Export         22636874.6
# Wholesale      82966575.7
# Name: Total Revenue, dtype: float64
