# %% [markdown]
# LOCATE AND ILOCATE

# %%
import pandas as pd

# %%
df=pd.read_excel("Sales Analysis Report (1) (1) (2).xlsx")

# %%
df
# Out:
#        OrderNumber  OrderDate  Ship Date  Customer Name Index      Channel  \
# 0      SO - 000225 2017-01-01 2017-01-13                   28    Wholesale
# 1     SO - 0003378 2017-01-01 2017-01-06                    7  Distributor
# 2     SO - 0003901 2017-01-01 2017-01-05                   12    Wholesale
# 3     SO - 0005126 2017-01-01 2017-01-17                    5    Wholesale
# 4     SO - 0005614 2017-01-01 2017-01-07                   27       Export
# ...            ...        ...        ...                  ...          ...
# 7986  SO - 0005237 2019-12-12 2019-12-16                   41    Wholesale
# 7987  SO - 0005477 2019-12-12 2019-12-27                   28  Distributor
# 7988  SO - 0006936 2019-12-12 2019-12-27                   30    Wholesale
# 7989  SO - 0007126 2019-12-12 2019-12-25                    6  Distributor
# 7990  SO - 0007668 2019-12-12 2019-12-25                    4    Wholesale
#
#      Currency Code Warehouse Code  Region Index  Product  Index  \
# ...

# %%
df.head(20)
# Out:
#      OrderNumber  OrderDate  Ship Date  Customer Name Index      Channel  \
# 0    SO - 000225 2017-01-01 2017-01-13                   28    Wholesale
# 1   SO - 0003378 2017-01-01 2017-01-06                    7  Distributor
# 2   SO - 0003901 2017-01-01 2017-01-05                   12    Wholesale
# 3   SO - 0005126 2017-01-01 2017-01-17                    5    Wholesale
# 4   SO - 0005614 2017-01-01 2017-01-07                   27       Export
# 5   SO - 0005781 2017-01-01 2017-01-15                   44    Wholesale
# 6   SO - 0002911 2017-01-02 2017-01-15                   37    Wholesale
# 7   SO - 0003527 2017-01-02 2017-01-19                    8    Wholesale
# 8   SO - 0004792 2017-01-02 2017-01-13                   14    Wholesale
# 9   SO - 0005414 2017-01-02 2017-01-05                   47    Wholesale
# 10  SO - 0005609 2017-01-02 2017-01-10                   22  Distributor
# 11  SO - 0006308 2017-01-02 2017-01-19                   39    Wholesale
# ...

# %%
df.loc[0:20]
# Out:
#      OrderNumber  OrderDate  Ship Date  Customer Name Index      Channel  \
# 0    SO - 000225 2017-01-01 2017-01-13                   28    Wholesale
# 1   SO - 0003378 2017-01-01 2017-01-06                    7  Distributor
# 2   SO - 0003901 2017-01-01 2017-01-05                   12    Wholesale
# 3   SO - 0005126 2017-01-01 2017-01-17                    5    Wholesale
# 4   SO - 0005614 2017-01-01 2017-01-07                   27       Export
# 5   SO - 0005781 2017-01-01 2017-01-15                   44    Wholesale
# 6   SO - 0002911 2017-01-02 2017-01-15                   37    Wholesale
# 7   SO - 0003527 2017-01-02 2017-01-19                    8    Wholesale
# 8   SO - 0004792 2017-01-02 2017-01-13                   14    Wholesale
# 9   SO - 0005414 2017-01-02 2017-01-05                   47    Wholesale
# 10  SO - 0005609 2017-01-02 2017-01-10                   22  Distributor
# 11  SO - 0006308 2017-01-02 2017-01-19                   39    Wholesale
# ...

# %%
df.loc[10:20]
# Out:
#      OrderNumber  OrderDate  Ship Date  Customer Name Index      Channel  \
# 10  SO - 0005609 2017-01-02 2017-01-10                   22  Distributor
# 11  SO - 0006308 2017-01-02 2017-01-19                   39    Wholesale
# 12  SO - 0006534 2017-01-02 2017-01-11                   46  Distributor
# 13  SO - 0007139 2017-01-02 2017-01-09                   45    Wholesale
# 14   SO - 000450 2017-01-03 2017-01-19                   20    Wholesale
# 15   SO - 000848 2017-01-03 2017-01-12                   36    Wholesale
# 16  SO - 0001724 2017-01-03 2017-01-19                   30    Wholesale
# 17  SO - 0002078 2017-01-03 2017-01-14                    5    Wholesale
# 18  SO - 0002795 2017-01-03 2017-01-09                   11    Wholesale
# 19  SO - 0003775 2017-01-03 2017-01-15                    5  Distributor
# 20  SO - 0004247 2017-01-03 2017-01-14                   14       Export
#
#    Currency Code Warehouse Code  Region Index  Product  Index  Order Quantity  \
# ...

# %%
df.loc[0:20,"Channel"]
# Out:
# 0       Wholesale
# 1     Distributor
# 2       Wholesale
# 3       Wholesale
# 4          Export
# 5       Wholesale
# 6       Wholesale
# 7       Wholesale
# 8       Wholesale
# 9       Wholesale
# 10    Distributor
# 11      Wholesale
# 12    Distributor
# 13      Wholesale
# 14      Wholesale
# 15      Wholesale
# 16      Wholesale
# 17      Wholesale
# 18      Wholesale
# 19    Distributor
# 20         Export
# Name: Channel, dtype: object

# %%
df.loc[10:20,"Channel":"Region Index"]
# Out:
#         Channel Currency Code Warehouse Code  Region Index
# 10  Distributor           NZD         AXW291             5
# 11    Wholesale           USD         AXW291            42
# 12  Distributor           NZD         AXW291            87
# 13    Wholesale           NZD         AXW291            80
# 14    Wholesale           EUR         AXW291            38
# 15    Wholesale           NZD         AXW291            97
# 16    Wholesale           AUD         AXW291            88
# 17    Wholesale           GBP         AXW291             6
# 18    Wholesale           NZD         AXW291            95
# 19  Distributor           GBP         AXW291            37
# 20       Export           NZD         AXW291            53

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7991 entries, 0 to 7990
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   OrderNumber          7991 non-null   object
#  1   OrderDate            7991 non-null   datetime64[ns]
#  2   Ship Date            7991 non-null   datetime64[ns]
#  3   Customer Name Index  7991 non-null   int64
#  4   Channel              7991 non-null   object
#  5   Currency Code        7991 non-null   object
#  6   Warehouse Code       7991 non-null   object
#  7   Region Index         7991 non-null   int64
#  8   Product  Index       7991 non-null   int64
#  9   Order Quantity       7991 non-null   int64
#  10  Unit Price           7991 non-null   float64
#  11  Total Unit Cost      7991 non-null   float64
#  12  Total Revenue        7991 non-null   float64
# dtypes: datetime64[ns](2), float64(3), int64(4), object(4)
# memory usage: 811.7+ KB

# %%
df.loc[0:5,"OrderDate":"Warehouse Code"]
# Out:
#    OrderDate  Ship Date  Customer Name Index      Channel Currency Code  \
# 0 2017-01-01 2017-01-13                   28    Wholesale           NZD
# 1 2017-01-01 2017-01-06                    7  Distributor           NZD
# 2 2017-01-01 2017-01-05                   12    Wholesale           NZD
# 3 2017-01-01 2017-01-17                    5    Wholesale           USD
# 4 2017-01-01 2017-01-07                   27       Export           NZD
# 5 2017-01-01 2017-01-15                   44    Wholesale           GBP
#
#   Warehouse Code
# 0         AXW291
# 1         AXW291
# 2         AXW291
# 3         AXW291
# 4         AXW291
# 5         AXW291

# %%
df.loc[:,"OrderDate":"Warehouse Code"]
# Out:
#       OrderDate  Ship Date  Customer Name Index      Channel Currency Code  \
# 0    2017-01-01 2017-01-13                   28    Wholesale           NZD
# 1    2017-01-01 2017-01-06                    7  Distributor           NZD
# 2    2017-01-01 2017-01-05                   12    Wholesale           NZD
# 3    2017-01-01 2017-01-17                    5    Wholesale           USD
# 4    2017-01-01 2017-01-07                   27       Export           NZD
# ...         ...        ...                  ...          ...           ...
# 7986 2019-12-12 2019-12-16                   41    Wholesale           NZD
# 7987 2019-12-12 2019-12-27                   28  Distributor           AUD
# 7988 2019-12-12 2019-12-27                   30    Wholesale           NZD
# 7989 2019-12-12 2019-12-25                    6  Distributor           USD
# 7990 2019-12-12 2019-12-25                    4    Wholesale           NZD
#
#      Warehouse Code
# 0            AXW291
# 1            AXW291
# ...

# %%
df.loc[0:10,["OrderDate","Total Revenue","Warehouse Code"]]
# Out:
#     OrderDate  Total Revenue Warehouse Code
# 0  2017-01-01        14994.6         AXW291
# 1  2017-01-01        25868.7         AXW291
# 2  2017-01-01         8643.0         AXW291
# 3  2017-01-01         5869.2         AXW291
# 4  2017-01-01        16368.1         AXW291
# 5  2017-01-01        18331.2         AXW291
# 6  2017-01-02         5467.2         AXW291
# 7  2017-01-02        18719.8         AXW291
# 8  2017-01-02         1005.0         AXW291
# 9  2017-01-02        12850.6         AXW291
# 10 2017-01-02        27764.8         AXW291

# %%
df.set_index("Product  Index",inplace=True)

# %%
df
# Out:
#                  OrderNumber  OrderDate  Ship Date  Customer Name Index  \
# Product  Index
# 11               SO - 000225 2017-01-01 2017-01-13                   28
# 7               SO - 0003378 2017-01-01 2017-01-06                    7
# 13              SO - 0003901 2017-01-01 2017-01-05                   12
# 7               SO - 0005126 2017-01-01 2017-01-17                    5
# 6               SO - 0005614 2017-01-01 2017-01-07                   27
# ...                      ...        ...        ...                  ...
# 9               SO - 0005237 2019-12-12 2019-12-16                   41
# 2               SO - 0005477 2019-12-12 2019-12-27                   28
# 1               SO - 0006936 2019-12-12 2019-12-27                   30
# 5               SO - 0007126 2019-12-12 2019-12-25                    6
# 13              SO - 0007668 2019-12-12 2019-12-25                    4
#
#                     Channel Currency Code Warehouse Code  Region Index  \
# ...

# %%
df.sort_index(inplace=True)

# %%
df
# Out:
#                  OrderNumber  OrderDate  Ship Date  Customer Name Index  \
# Product  Index
# 1               SO - 0003690 2018-03-06 2018-03-16                   37
# 1               SO - 0006864 2018-06-24 2018-07-02                   30
# 1                SO - 000891 2017-11-17 2017-11-23                   21
# 1               SO - 0003373 2019-10-27 2019-11-06                   41
# 1               SO - 0001081 2018-06-23 2018-07-01                   30
# ...                      ...        ...        ...                  ...
# 14              SO - 0001616 2019-07-31 2019-08-13                   37
# 14              SO - 0006883 2018-10-14 2018-10-20                   42
# 14              SO - 0003751 2018-10-24 2018-11-09                   28
# 14              SO - 0005640 2018-09-18 2018-09-21                   38
# 14              SO - 0007111 2018-05-07 2018-05-11                   31
#
#                     Channel Currency Code Warehouse Code  Region Index  \
# ...

# %%
df.loc[1:2]
# Out:
#                  OrderNumber  OrderDate  Ship Date  Customer Name Index  \
# Product  Index
# 1               SO - 0003690 2018-03-06 2018-03-16                   37
# 1               SO - 0006864 2018-06-24 2018-07-02                   30
# 1                SO - 000891 2017-11-17 2017-11-23                   21
# 1               SO - 0003373 2019-10-27 2019-11-06                   41
# 1               SO - 0001081 2018-06-23 2018-07-01                   30
# ...                      ...        ...        ...                  ...
# 2               SO - 0007683 2018-10-08 2018-10-20                    3
# 2                SO - 000525 2019-11-20 2019-11-23                   43
# 2               SO - 0002793 2017-03-17 2017-04-04                   17
# 2               SO - 0005722 2019-10-11 2019-10-17                   13
# 2               SO - 0006897 2019-06-06 2019-06-18                   46
#
#                     Channel Currency Code Warehouse Code  Region Index  \
# ...

# %%
df.iloc[1]
# Out:
# OrderNumber                   SO - 0006864
# OrderDate              2018-06-24 00:00:00
# Ship Date              2018-07-02 00:00:00
# Customer Name Index                     30
# Channel                          Wholesale
# Currency Code                          NZD
# Warehouse Code                      GUT930
# Region Index                            17
# Order Quantity                           6
# Unit Price                          3999.9
# Total Unit Cost                   2519.937
# Total Revenue                      23999.4
# Name: 1, dtype: object

# %%
df.iloc[1,4:8]
# Out:
# Channel           Wholesale
# Currency Code           NZD
# Warehouse Code       GUT930
# Region Index             17
# Name: 1, dtype: object

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#       Product  Index   OrderNumber  OrderDate  Ship Date  Customer Name Index  \
# 0                  1  SO - 0003690 2018-03-06 2018-03-16                   37
# 1                  1  SO - 0006864 2018-06-24 2018-07-02                   30
# 2                  1   SO - 000891 2017-11-17 2017-11-23                   21
# 3                  1  SO - 0003373 2019-10-27 2019-11-06                   41
# 4                  1  SO - 0001081 2018-06-23 2018-07-01                   30
# ...              ...           ...        ...        ...                  ...
# 7986              14  SO - 0001616 2019-07-31 2019-08-13                   37
# 7987              14  SO - 0006883 2018-10-14 2018-10-20                   42
# 7988              14  SO - 0003751 2018-10-24 2018-11-09                   28
# 7989              14  SO - 0005640 2018-09-18 2018-09-21                   38
# 7990              14  SO - 0007111 2018-05-07 2018-05-11                   31
#
# ...

# %%
df_export=df.loc[df["Channel"]=="Export"]
df_export
# Out:
#       Product  Index   OrderNumber  OrderDate  Ship Date  Customer Name Index  \
# 2                  1   SO - 000891 2017-11-17 2017-11-23                   21
# 8                  1  SO - 0005303 2018-11-29 2018-12-08                   13
# 11                 1  SO - 0005251 2017-11-17 2017-11-21                    1
# 12                 1  SO - 0005445 2017-11-17 2017-12-05                   34
# 13                 1  SO - 0005170 2018-12-01 2018-12-13                   37
# ...              ...           ...        ...        ...                  ...
# 7948              14  SO - 0005965 2017-11-09 2017-11-23                   37
# 7960              14  SO - 0003022 2017-08-04 2017-08-18                   25
# 7967              14  SO - 0001087 2019-08-22 2019-08-31                   15
# 7973              14  SO - 0002843 2017-12-31 2018-01-10                   16
# 7990              14  SO - 0007111 2018-05-07 2018-05-11                   31
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7991 entries, 0 to 7990
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Product  Index       7991 non-null   int64
#  1   OrderNumber          7991 non-null   object
#  2   OrderDate            7991 non-null   datetime64[ns]
#  3   Ship Date            7991 non-null   datetime64[ns]
#  4   Customer Name Index  7991 non-null   int64
#  5   Channel              7991 non-null   object
#  6   Currency Code        7991 non-null   object
#  7   Warehouse Code       7991 non-null   object
#  8   Region Index         7991 non-null   int64
#  9   Order Quantity       7991 non-null   int64
#  10  Unit Price           7991 non-null   float64
#  11  Total Unit Cost      7991 non-null   float64
#  12  Total Revenue        7991 non-null   float64
# dtypes: datetime64[ns](2), float64(3), int64(4), object(4)
# memory usage: 811.7+ KB

# %%
df_exp=df.loc[(df["Channel"]=="Export")&(df["Currency Code"]=="NZD")]
df_exp
# Out:
#       Product  Index   OrderNumber  OrderDate  Ship Date  Customer Name Index  \
# 8                  1  SO - 0005303 2018-11-29 2018-12-08                   13
# 12                 1  SO - 0005445 2017-11-17 2017-12-05                   34
# 13                 1  SO - 0005170 2018-12-01 2018-12-13                   37
# 25                 1  SO - 0002711 2018-11-24 2018-12-05                   17
# 52                 1  SO - 0001034 2017-05-24 2017-05-27                   22
# ...              ...           ...        ...        ...                  ...
# 7927              14  SO - 0006005 2018-04-12 2018-04-16                    9
# 7937              14  SO - 0003216 2018-03-04 2018-03-16                   25
# 7960              14  SO - 0003022 2017-08-04 2017-08-18                   25
# 7973              14  SO - 0002843 2017-12-31 2018-01-10                   16
# 7990              14  SO - 0007111 2018-05-07 2018-05-11                   31
#
# ...

# %%
df_exp1=df.loc[(df["Channel"]=="Export")&(df["Currency Code"]=="NZD")&(df["Product  Index"]=="2")]
df_exp1
# Out:
# Empty DataFrame
# Columns: [Product  Index, OrderNumber, OrderDate, Ship Date, Customer Name Index, Channel, Currency Code, Warehouse Code, Region Index, Order Quantity, Unit Price, Total Unit Cost, Total Revenue]
# Index: []
