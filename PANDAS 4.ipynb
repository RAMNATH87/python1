# %% [markdown]
# PANDAS DAY 4

# %%
import pandas as pd

# %%
df=pd.read_excel("billing2.xlsx")
df
# Out:
#         name             Address model  quantity   Price  Amount
# 0     yukesh    kk nagar-chennai    RN         1     NaN     NaN
# 1    kishore  pallavaram-chennai    FN         1  1000.0     NaN
# 2     vidhya     t nagar-chennai    RN         3   500.0  1000.0
# 3     arisha    annur-coimbatore    FN         2     NaN     NaN
# 4  parthiban   koyembedu-chennai    RN         2   500.0     NaN
# 5   vaishnav    kk nagar-chennai    RN         4     NaN     NaN
# 6  parthiban     t nagar-chennai    RN         2   500.0  1000.0

# %%
df.shape
# Out:
# (7, 6)

# %%
df_drop=df.dropna()
df_drop
# Out:
#         name          Address model  quantity  Price  Amount
# 2     vidhya  t nagar-chennai    RN         3  500.0  1000.0
# 6  parthiban  t nagar-chennai    RN         2  500.0  1000.0

# %%
df
# Out:
#         name             Address model  quantity   Price  Amount
# 0     yukesh    kk nagar-chennai    RN         1     NaN     NaN
# 1    kishore  pallavaram-chennai    FN         1  1000.0     NaN
# 2     vidhya     t nagar-chennai    RN         3   500.0  1000.0
# 3     arisha    annur-coimbatore    FN         2     NaN     NaN
# 4  parthiban   koyembedu-chennai    RN         2   500.0     NaN
# 5   vaishnav    kk nagar-chennai    RN         4     NaN     NaN
# 6  parthiban     t nagar-chennai    RN         2   500.0  1000.0

# %%
df.fillna("500")
# Out:
#         name             Address model  quantity   Price  Amount
# 0     yukesh    kk nagar-chennai    RN         1     500     500
# 1    kishore  pallavaram-chennai    FN         1  1000.0     500
# 2     vidhya     t nagar-chennai    RN         3   500.0  1000.0
# 3     arisha    annur-coimbatore    FN         2     500     500
# 4  parthiban   koyembedu-chennai    RN         2   500.0     500
# 5   vaishnav    kk nagar-chennai    RN         4     500     500
# 6  parthiban     t nagar-chennai    RN         2   500.0  1000.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   name      7 non-null      object
#  1   Address   7 non-null      object
#  2   model     7 non-null      object
#  3   quantity  7 non-null      int64
#  4   Price     4 non-null      float64
#  5   Amount    2 non-null      float64
# dtypes: float64(2), int64(1), object(3)
# memory usage: 468.0+ bytes

# %%
df["Price"].fillna("500")
# Out:
# 0       500
# 1    1000.0
# 2     500.0
# 3       500
# 4     500.0
# 5       500
# 6     500.0
# Name: Price, dtype: object

# %%
df["Amount"].fillna("700")
# Out:
# 0       700
# 1       700
# 2    1000.0
# 3       700
# 4       700
# 5       700
# 6    1000.0
# Name: Amount, dtype: object

# %%
df.describe()
# Out:
#        quantity   Price  Amount
# count  7.000000     4.0     2.0
# mean   2.142857   625.0  1000.0
# std    1.069045   250.0     0.0
# min    1.000000   500.0  1000.0
# 25%    1.500000   500.0  1000.0
# 50%    2.000000   500.0  1000.0
# 75%    2.500000   625.0  1000.0
# max    4.000000  1000.0  1000.0

# %%
#df=df["Price"].fillna(625.0)

df["Price"].fillna(625.0)
# Out:
# 0     625.0
# 1    1000.0
# 2     500.0
# 3     625.0
# 4     500.0
# 5     625.0
# 6     500.0
# Name: Price, dtype: float64

# %%
df
# Out:
#         name             Address model  quantity   Price  Amount
# 0     yukesh    kk nagar-chennai    RN         1     NaN     NaN
# 1    kishore  pallavaram-chennai    FN         1  1000.0     NaN
# 2     vidhya     t nagar-chennai    RN         3   500.0  1000.0
# 3     arisha    annur-coimbatore    FN         2     NaN     NaN
# 4  parthiban   koyembedu-chennai    RN         2   500.0     NaN
# 5   vaishnav    kk nagar-chennai    RN         4     NaN     NaN
# 6  parthiban     t nagar-chennai    RN         2   500.0  1000.0

# %%
df.ffill()
# Out:
#         name             Address model  quantity   Price  Amount
# 0     yukesh    kk nagar-chennai    RN         1     NaN     NaN
# 1    kishore  pallavaram-chennai    FN         1  1000.0     NaN
# 2     vidhya     t nagar-chennai    RN         3   500.0  1000.0
# 3     arisha    annur-coimbatore    FN         2   500.0  1000.0
# 4  parthiban   koyembedu-chennai    RN         2   500.0  1000.0
# 5   vaishnav    kk nagar-chennai    RN         4   500.0  1000.0
# 6  parthiban     t nagar-chennai    RN         2   500.0  1000.0

# %%
df.bfill()
# Out:
#         name             Address model  quantity   Price  Amount
# 0     yukesh    kk nagar-chennai    RN         1  1000.0  1000.0
# 1    kishore  pallavaram-chennai    FN         1  1000.0  1000.0
# 2     vidhya     t nagar-chennai    RN         3   500.0  1000.0
# 3     arisha    annur-coimbatore    FN         2   500.0  1000.0
# 4  parthiban   koyembedu-chennai    RN         2   500.0  1000.0
# 5   vaishnav    kk nagar-chennai    RN         4   500.0  1000.0
# 6  parthiban     t nagar-chennai    RN         2   500.0  1000.0

# %%
df["Price"].ffill()
# Out:
# 0       NaN
# 1    1000.0
# 2     500.0
# 3     500.0
# 4     500.0
# 5     500.0
# 6     500.0
# Name: Price, dtype: float64

# %%
df_am=df["Amount"].bfill()

# %%
df_am.astype("int64")
# Out:
# 0    1000
# 1    1000
# 2    1000
# 3    1000
# 4    1000
# 5    1000
# 6    1000
# Name: Amount, dtype: int64

# %%
df
# Out:
#         name             Address model  quantity   Price  Amount
# 0     yukesh    kk nagar-chennai    RN         1     NaN     NaN
# 1    kishore  pallavaram-chennai    FN         1  1000.0     NaN
# 2     vidhya     t nagar-chennai    RN         3   500.0  1000.0
# 3     arisha    annur-coimbatore    FN         2     NaN     NaN
# 4  parthiban   koyembedu-chennai    RN         2   500.0     NaN
# 5   vaishnav    kk nagar-chennai    RN         4     NaN     NaN
# 6  parthiban     t nagar-chennai    RN         2   500.0  1000.0

# %%
dfnum=df[["quantity","Price"]]
dfnum
# Out:
#    quantity   Price
# 0         1     NaN
# 1         1  1000.0
# 2         3   500.0
# 3         2     NaN
# 4         2   500.0
# 5         4     NaN
# 6         2   500.0

# %%
import pandas as pd
import numpy as np

# Create a dataset for the example (Time, Temperature, and Humidity)
data = {
'Temperature': [22, 23, 26, 28, 30, 32], # Increasing temperature
'Humidity': [55, 63, np.nan, 66, np.nan, 68] # Missing humidity at higher temperatures
}

# Convert to a DataFrame
df6 = pd.DataFrame(data)

# %%
df6
# Out:
#    Temperature  Humidity
# 0           22      55.0
# 1           23      63.0
# 2           26       NaN
# 3           28      66.0
# 4           30       NaN
# 5           32      68.0

# %%
df6.corr()
# Out:
#              Temperature  Humidity
# Temperature     1.000000  0.853642
# Humidity        0.853642  1.000000

# %%
import seaborn as sns

# %%
sns.scatterplot(x="Temperature",y="Humidity",data=df6)
# Out:
# <Axes: xlabel='Temperature', ylabel='Humidity'>

# %%
df6=df6.interpolate(method="polynomial",order=2)

# %%
df6
# Out:
#    Temperature   Humidity
# 0           22  55.000000
# 1           23  63.000000
# 2           26  65.705882
# 3           28  66.000000
# 4           30  66.764706
# 5           32  68.000000
