# %%
import pandas as pd

# %%
df_loc=pd.read_excel("location.xlsx")

# %%
df_hr=pd.read_excel("hr.xlsx")

# %%
df_pro=pd.read_excel("pro.xlsx")

# %%
df_loc
# Out:
#    location_ID   Location
# 0          125    chennai
# 1          135     mumbai
# 2          145      noida
# 3          175  bangalore
# 4          187  hyderabad

# %%
df_hr
# Out:
#      ID     Name     Role  Salary  location_ID
# 0  1001    Selva  Manager   50000          125
# 1  1002     Mani  Manager   50000          165
# 2  1003   Naveen       L1   30000          135
# 3  1004  agustin       A1   20000          125
# 4  1005  vincent       L1   30000          125
# 5  1006   brutus       A1   20000          135
# 6  1007    bruce       L2   25000          165
# 7  1008  abishek       A2   18000          125
# 8  1009  madthan       L2   25000          125

# %%
df_pro
# Out:
#      ID projects
# 0  1001     Data
# 1  1002     App
# 2  1003     Data
# 3  1004     App
# 4  1005     Data
# 5  1006     App
# 6  1007     Data
# 7  1008     App
# 8  1009     Data

# %%
data1=df_hr.merge(df_loc,how="left")
data1
# Out:
#      ID     Name     Role  Salary  location_ID Location
# 0  1001    Selva  Manager   50000          125  chennai
# 1  1002     Mani  Manager   50000          165      NaN
# 2  1003   Naveen       L1   30000          135   mumbai
# 3  1004  agustin       A1   20000          125  chennai
# 4  1005  vincent       L1   30000          125  chennai
# 5  1006   brutus       A1   20000          135   mumbai
# 6  1007    bruce       L2   25000          165      NaN
# 7  1008  abishek       A2   18000          125  chennai
# 8  1009  madthan       L2   25000          125  chennai

# %%
data=data1.merge(df_pro,how="inner")

# %%
data
# Out:
#      ID     Name     Role  Salary  location_ID Location projects
# 0  1001    Selva  Manager   50000          125  chennai     Data
# 1  1002     Mani  Manager   50000          165      NaN     App
# 2  1003   Naveen       L1   30000          135   mumbai     Data
# 3  1004  agustin       A1   20000          125  chennai     App
# 4  1005  vincent       L1   30000          125  chennai     Data
# 5  1006   brutus       A1   20000          135   mumbai     App
# 6  1007    bruce       L2   25000          165      NaN     Data
# 7  1008  abishek       A2   18000          125  chennai     App
# 8  1009  madthan       L2   25000          125  chennai     Data

# %%
data.head()
# Out:
#      ID     Name     Role  Salary  location_ID Location projects
# 0  1001    Selva  Manager   50000          125  chennai     Data
# 1  1002     Mani  Manager   50000          165      NaN     App
# 2  1003   Naveen       L1   30000          135   mumbai     Data
# 3  1004  agustin       A1   20000          125  chennai     App
# 4  1005  vincent       L1   30000          125  chennai     Data

# %%
data.shape
# Out:
# (9, 7)

# %%
import pandas as pd

# %%
df5=pd.read_excel("Sales Analysis Report (1) (1) (2).xlsx")
df5
# Out:
#        OrderNumber  OrderDate  Ship Date  Customer Name Index      Channel  \
# 0      SO - 000225 2017-01-01 2017-01-13                   28    Wholesale
# 1     SO - 0003378 2017-01-01 2017-01-06                    7  Distributor
# 2     SO - 0003901 2017-01-01 2017-01-05                   12    Wholesale
# 3     SO - 0005126 2017-01-01 2017-01-17                    5    Wholesale
# 4     SO - 0005614 2017-01-01 2017-01-07                   27       Export
# ...            ...        ...        ...                  ...          ...
# 7986  SO - 0005237 2019-12-12 2019-12-16                   41    Wholesale
# 7987  SO - 0005477 2019-12-12 2019-12-27                   28  Distributor
# 7988  SO - 0006936 2019-12-12 2019-12-27                   30    Wholesale
# 7989  SO - 0007126 2019-12-12 2019-12-25                    6  Distributor
# 7990  SO - 0007668 2019-12-12 2019-12-25                    4    Wholesale
#
#      Currency Code Warehouse Code  Region Index  Product  Index  \
# ...

# %%
df5.head()
# Out:
#     OrderNumber  OrderDate  Ship Date  Customer Name Index      Channel  \
# 0   SO - 000225 2017-01-01 2017-01-13                   28    Wholesale
# 1  SO - 0003378 2017-01-01 2017-01-06                    7  Distributor
# 2  SO - 0003901 2017-01-01 2017-01-05                   12    Wholesale
# 3  SO - 0005126 2017-01-01 2017-01-17                    5    Wholesale
# 4  SO - 0005614 2017-01-01 2017-01-07                   27       Export
#
#   Currency Code Warehouse Code  Region Index  Product  Index  Order Quantity  \
# 0           NZD         AXW291            71              11               6
# 1           NZD         AXW291            54               7              11
# 2           NZD         AXW291            58              13               5
# 3           USD         AXW291            29               7               6
# 4           NZD         AXW291            31               6               7
#
#    Unit Price  Total Unit Cost  Total Revenue
# ...

# %%
df5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7991 entries, 0 to 7990
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   OrderNumber          7991 non-null   object
#  1   OrderDate            7991 non-null   datetime64[ns]
#  2   Ship Date            7991 non-null   datetime64[ns]
#  3   Customer Name Index  7991 non-null   int64
#  4   Channel              7991 non-null   object
#  5   Currency Code        7991 non-null   object
#  6   Warehouse Code       7991 non-null   object
#  7   Region Index         7991 non-null   int64
#  8   Product  Index       7991 non-null   int64
#  9   Order Quantity       7991 non-null   int64
#  10  Unit Price           7991 non-null   float64
#  11  Total Unit Cost      7991 non-null   float64
#  12  Total Revenue        7991 non-null   float64
# dtypes: datetime64[ns](2), float64(3), int64(4), object(4)
# memory usage: 811.7+ KB

# %%
import seaborn as sns

# %%
sns.boxplot(x="Order Quantity",data=df5)
# Out:
# <Axes: xlabel='Order Quantity'>

# %%
sns.histplot(x="Order Quantity",data=df5)
# Out:
# <Axes: xlabel='Order Quantity', ylabel='Count'>

# %%
sns.histplot(x="Order Quantity",data=df5,bins=5)
# Out:
# <Axes: xlabel='Order Quantity', ylabel='Count'>

# %% [markdown]
# TASK

# %%
data.isnull().sum()
# Out:
# ID             0
# Name           0
# Role           0
# Salary         0
# location_ID    0
# Location       2
# projects       0
# dtype: int64

# %%
data.describe()
# Out:
#                 ID        Salary  location_ID
# count     9.000000      9.000000     9.000000
# mean   1005.000000  29777.777778   136.111111
# std       2.738613  12214.517774    16.914819
# min    1001.000000  18000.000000   125.000000
# 25%    1003.000000  20000.000000   125.000000
# 50%    1005.000000  25000.000000   125.000000
# 75%    1007.000000  30000.000000   135.000000
# max    1009.000000  50000.000000   165.000000

# %%
data.fillna(("mumbai"),inplace=True)

# %%
data.isnull()
# Out:
#       ID   Name   Role  Salary  location_ID  Location  projects
# 0  False  False  False   False        False     False     False
# 1  False  False  False   False        False     False     False
# 2  False  False  False   False        False     False     False
# 3  False  False  False   False        False     False     False
# 4  False  False  False   False        False     False     False
# 5  False  False  False   False        False     False     False
# 6  False  False  False   False        False     False     False
# 7  False  False  False   False        False     False     False
# 8  False  False  False   False        False     False     False

# %%
data
# Out:
#      ID     Name     Role  Salary  location_ID Location projects
# 0  1001    Selva  Manager   50000          125  chennai     Data
# 1  1002     Mani  Manager   50000          165   mumbai     App
# 2  1003   Naveen       L1   30000          135   mumbai     Data
# 3  1004  agustin       A1   20000          125  chennai     App
# 4  1005  vincent       L1   30000          125  chennai     Data
# 5  1006   brutus       A1   20000          135   mumbai     App
# 6  1007    bruce       L2   25000          165   mumbai     Data
# 7  1008  abishek       A2   18000          125  chennai     App
# 8  1009  madthan       L2   25000          125  chennai     Data

# %%
df1=pd.read_excel("weight-height (1).csv")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[75], line 1
# ----> 1 df1=pd.read_excel("weight-height (1).csv")
#
# File ~\anaconda3\Lib\site-packages\pandas\io\excel\_base.py:495, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493 if not isinstance(io, ExcelFile):
#     494     should_close = True
# --> 495     io = ExcelFile(
#     496         io,
#     497         storage_options=storage_options,
#     498         engine=engine,
#     499         engine_kwargs=engine_kwargs,
#     500     )
#     501 elif engine and engine != io.engine:
#     502     raise ValueError(
# ...
