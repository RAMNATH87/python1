# %%
from abc import ABC, abstractmethod
class bank(ABC):
    @abstractmethod
    def savings_account(self):
        pass
    @abstractmethod
    def joint_account(self):
        pass
    @abstractmethod
    def salary_account(self):
        pass
    @abstractmethod
    def business_account(self):
        pass

class student(bank):
    def __init__ (self,age):
        self.age=age
    def joint_account(self):
        if self.age>18:
            print(f"sorry, you cannot open a joint account because your age is {self.age}")
        elif self.age<15:
            print(f"as your age is {self.age}, you got a 10% subsidy for opening a joint account")
        elif self.age>=15 and self.age<=18:
            print(f"as your age is {self.age}, you got a 5% subsidy for opening a joint account")
    def savings_account(self):
        pass
    def business_account(self):
        pass
    def salary_account(self):
        pass
obj=student(12)
obj.joint_account()
# Out:
# as your age is 12, you got a 10% subsidy for opening a joint account

# %%
from abc import ABC, abstractmethod
class bank(ABC):
    @abstractmethod
    def savings_account(self):
        pass
    @abstractmethod
    def joint_account(self):
        pass
    @abstractmethod
    def salary_account(self):
        pass
    @abstractmethod
    def business_account(self):
        pass

class student(bank):
    def __init__ (self,age):
        self.age=age
    def joint_account(self):
        if self.age>18:
            print(f"sorry, you cannot open a joint account because your age is {self.age}")
        elif self.age<15:
            print(f"as your age is {self.age}, you got a 10% subsidy for opening a joint account")
        elif self.age>=15 and self.age<=18:
            print(f"as your age is {self.age}, you got a 5% subsidy for opening a joint account")
    def savings_account(self):
        pass
    def business_account(self):
        pass
    def salary_account(self):
        pass

class college(bank):
    def __init__(self,name,degree,clg_name,cgpa,passed_out):
        if passed_out
obj=student(12)
obj.joint_account()

# %% [markdown]
# ERROR HANDLING AND EXCEPTIONAL HANDLING:

# %%
try:
    a=3
    b=2.5
    c=a/b
    print(c)
except ZeroDivisionError:
    print("do not enter zero in b")
except TypeError:
    print("you should only enter integers")
finally:
    print("the program is over")
# Out:
# 1.2
# the program is over

# %%
from abc import ABC, abstractmethod
class bank(ABC):
    @abstractmethod
    def savings_account(self):
        pass
    @abstractmethod
    def joint_account(self):
        pass
    @abstractmethod
    def salary_account(self):
        pass
    @abstractmethod
    def business_account(self):
        pass

class student(bank):
    def __init__ (self,age):
        self.age=age
    def joint_account(self):
        if self.age>18:
            print(f"sorry, you cannot open a joint account because your age is {self.age}")
        elif self.age<15:
            print(f"as your age is {self.age}, you got a 10% subsidy for opening a joint account")
        elif self.age>=15 and self.age<=18:
            print(f"as your age is {self.age}, you got a 5% subsidy for opening a joint account")
    def savings_account(self):
        pass
    def business_account(self):
        pass
    def salary_account(self):
        pass

class college(bank):
    def __init__(self,name,degree,clg_name,passed_out,cgpa):
        self.name=name
        self.degree=degree
        self.clg_name=clg_name
        self.passed_out=passed_out
        self.__cgpa=cgpa
    def savings_account(self):
        if self.passed_out>=2020:
            if self.degree=="BE":
                print("bank will provide 1000")
            elif self.degree=="BSC":
                print("bank will provide 4000")

        else:
            print("not elidgble")
           
    def business_account(self):
        pass
    def salary_account(self):
        pass
    def joint_account(self):
        pass
class business_class(bank):
    def __init__ (self,aadhar,name,revenue,company):
        self.aadhar=aadhar
        self.name=name
        self.revenue=revenue
        self.company=company
    def business_account(self):
        
        if len(self.aadhar)==12:
            if self.revenue>=1000000:
                tax=self.revenue/10
                print(f"you have to pay {tax} as tax")
            else:
                print("no tax")
        else :
            print("enter 12 digit aadhar number")
    def savings_account(self):
        pass
    def joint_account(self):
        pass
    def salary_account(self):
        pass
    
class employee(bank):
    def __init__ (self,age,pan,name,salary,company,location):
        self.age=age
        self.pan=pan
        self.name=name
        self.salary=salary
        self.company=company
        self.location=location
    def salary_account(self):
        print(f"your name is {self.name}, {self.age} years old, your salary is {self.salary} and you are from {self.location}")
        if self.salary<=300000:
            tax=self.salary/15
            print(f"you have to pay {tax} as tax")
        elif self.salary>300000 and self.salary<=700000:
            tax=self.salary/23
            print(f"you have to pay {tax} as tax")
        elif self.salary>700000 and self.salary<=1200000:
            tax=self.salary/27
            print(f"you have to pay {tax} as tax")
        else :
            tax=self.salary/30
            print(f"you have to pay {tax} as tax")
    def savings_account(self):
        pass
    def joint_account(self):
        pass
    def business_account(self):
        pass
        
            
    
    




obj=student(12)
obj.joint_account()       
obj1=college("ram","BE","scad",2019,7.5)
obj1.savings_account()
obj2=business_class("123456789101","ram",1000000,"tcs")
obj2.business_account()
obj3=employee(22,121233,"ram",1000000,"tcs","tvl")
obj3.salary_account()
# Out:
# as your age is 12, you got a 10% subsidy for opening a joint account
# not elidgble
# you have to pay 100000.0 as tax
# your name is ram, 22 years old, your salary is 1000000 and you are from tvl
# you have to pay 37037.03703703704 as tax
